# %%
import matplotlib.pyplot as plt   # 引入pyplot 模块   
import numpy as np     # 引入numpy 库   
data = np.loadtxt("test.dat")  #加载成列表
plt.plot(data[:,0],data[:,1:])  #:代表所有行，第一列代表x轴，第二列代表y轴. 也可以把多维数组传递进来，可以自动拆分。
plt.show()
print(data[:,1])
# Out:
# [2. 7. 8.]
